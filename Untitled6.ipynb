# %%
import pandas as pd

# %%
df = pd.read_csv('test.csv')
df.head()
# Out:
#                               company                                title  \
# 0       บริษัท ดีเวอร์ฮูด เอชที จำกัด  Junior and Data Analytics (Trainee)
# 1  บริษัท เด็กดี อินเตอร์แอคทีฟ จำกัด                    Android Developer
# 2  บริษัท เด็กดี อินเตอร์แอคทีฟ จำกัด                        iOS Developer
# 3    บริษัท โกซอฟท์ (ประเทศไทย) จำกัด                       Data Scientist
# 4    บริษัท โกซอฟท์ (ประเทศไทย) จำกัด                 Full Stack Developer
#
#    quota   wage working_condition  \
# 0      2  300.0            Hybrid
# 1      1  150.0            Hybrid
# 2      1  150.0            Hybrid
# 3      2    NaN            Hybrid
# 4      1    NaN            Hybrid
#
#                                                 tags  selected
# 0  JavaScript, Data Analyst, SQL, FullStack, Pyth...        12
# 1                                                NaN         2
# 2                                                NaN         1
# ...

# %%
df.loc[
    
    ((df['selected'].astype(int) / df['quota'].astype(int)) <= 5)
]
# Out:
#                                 company                       title  quota  \
# 1    บริษัท เด็กดี อินเตอร์แอคทีฟ จำกัด           Android Developer      1
# 2    บริษัท เด็กดี อินเตอร์แอคทีฟ จำกัด               iOS Developer      1
# 3      บริษัท โกซอฟท์ (ประเทศไทย) จำกัด              Data Scientist      2
# 4      บริษัท โกซอฟท์ (ประเทศไทย) จำกัด        Full Stack Developer      1
# 5      บริษัท โกซอฟท์ (ประเทศไทย) จำกัด       Data Engineer Trainee      1
# ..                                  ...                         ...    ...
# 156              บริษัท กรีนมูนส์ จำกัด    Web Developer (Frontend)      1
# 157              บริษัท กรีนมูนส์ จำกัด  Back-end Engineer (Golang)      1
# 158              บริษัท กรีนมูนส์ จำกัด       QA / Software Tester       1
# 159              บริษัท กรีนมูนส์ จำกัด             Mobile Engineer      1
# 160        บริษัท โอสถสภา จำกัด (มหาชน)       Data Analytics Intern      2
#
#        wage working_condition  \
# 1     150.0            Hybrid
# ...

# %%
int(df['quota'].sum())
# Out:
# 316
